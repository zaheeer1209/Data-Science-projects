# %% [markdown]
# <a href="https://colab.research.google.com/github/zaheeer1209/Data-Science-projects/blob/main/functions_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function without parameters and return (user-defined)
def welcome():
 print("----- Welcome to Student Result System -----")
# Function with parameters (user-defined, no return value)
def display_student(name, rollno):
 print(f"Student Name: {name}")
 print(f"Roll Number : {rollno}")
# Function with return value (user-defined)
def calculate_total(marks):
# Using built-in function sum() to calculate total
  total = sum(marks)
  return total
# Function with parameters and return (user-defined)
def calculate_grade(average):
  if average >= 90:
    return "A+"
  elif average >= 75:
    return "A"
  elif average >= 60:
    return "B"
  elif average >= 35:
    return "C"
  else:
    return "Fail"
# ---------------- Main Program ----------------
# Calling user-defined functions
welcome()
# Student details (input can be taken, here given as sample)
name = "Zaheer"
rollno = 18
marks = [85, 90, 78, 88, 92] # marks in 5 subjects
display_student(name, rollno)
# Calling user-defined functions with built-in ones inside
total = calculate_total(marks) # user-defined
average = total / len(marks) # len() is built-in
grade = calculate_grade(average) # user-defined
# Output using built-in function print()
print("\nTotal Marks :", total)
# Out:
# ----- Welcome to Student Result System -----
# Student Name: Zaheer
# Roll Number : 18
#
# Total Marks : 433
