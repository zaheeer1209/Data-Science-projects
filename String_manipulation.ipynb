# %% [markdown]
# <a href="https://colab.research.google.com/github/zaheeer1209/Data-Science-projects/blob/main/String_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input string (student details)
student_info = " Name: Sara | Roll: 101 | Course: Python Programming "
# 1. Remove extra spaces
clean_info = student_info.strip()
# 2. Convert to uppercase and lowercase
print("Uppercase:", clean_info.upper())
print("Lowercase:", clean_info.lower())
# 3. Check if string starts and ends with certain words
print("Starts with 'Name':", clean_info.startswith("Name"))
print("Ends with 'ing':", clean_info.endswith("ing"))
# 4. Replace a word
new_info = clean_info.replace("Python", "Data Science")
print("After Replace:", new_info)
# 5. Split into parts
parts = clean_info.split("|")
print("Split Parts:", parts)
# 6. Join with commas
joined = ", ".join(parts)
print("Joined with commas:", joined)
# 7. Find and count
print("Position of 'Roll':", clean_info.find("Roll"))
print("Count of 'a':", clean_info.count("a"))
# 8. String formatting (f-string)
name = "Sara"
marks = 433
print(f"\nStudent {name} has scored {marks} marks successfully.")
# 9. Escape sequence
print("Line1\nLine2\tTabbed Example")
# Out:
# Uppercase: NAME: SARA | ROLL: 101 | COURSE: PYTHON PROGRAMMING
# Lowercase: name: sara | roll: 101 | course: python programming
# Starts with 'Name': True
# Ends with 'ing': True
# After Replace: Name: Sara | Roll: 101 | Course: Data Science Programming
# Split Parts: ['Name: Sara ', ' Roll: 101 ', ' Course: Python Programming']
# Joined with commas: Name: Sara ,  Roll: 101 ,  Course: Python Programming
# Position of 'Roll': 13
# Count of 'a': 4
#
# Student Sara has scored 433 marks successfully.
# Line1
# Line2	Tabbed Example
